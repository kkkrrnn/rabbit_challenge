# %%
# google driveのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# sys.pathの設定
import sys
sys.path.append('/content/drive/My Drive/DNN_code')

# %% [markdown]
# network modified
# layers

# %%
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# ReLU layer
class Relu:
  def __init__(self):
    self.mask = None

  def forward(self, x):
    # mask.shape = x.shape
    # True or Falseを要素として持つ
    self.mask = (x <= 0)
    out = x.copy()
    # Trueの箇所を0にする
    out[self.mask] = 0

    return out

  def backward(self, dout):
    # Trueの箇所を0にする
    dout[self.mask] = 0
    dx = dout

    return dx

# %%
# Affine layer(全結合layer)
class Affine:
  def __init__(self, W, b):
    self.W = W
    self.b = b

    self.x = None
    self.original_x_shape = None
    # 重み、バイアスパラメータの微分
    self.dW = None
    self.db = None

  def forward(self, x):
    out = np.dot(self.x, self.W) + self.b
    return out

  def backward(self, dout):
    dx = np.dot(dout, self.W.T)
    self.dW = np.dot(self.x.T, dout)
    self.db = np.sum(dout, axis=0)

    return dx

# %% [markdown]
# two layer network class

# %%
class TwoLayerNet:
  '''
  input_size : 入力層のノード数
  hidden_size : 隠れ層のノード数
  output_size : 出力層のノード数
  weight_init_std : 重みの初期化方法
  '''
  def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
    # 重みの初期化
    self.params = {}
    self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
    self.params['W2'] = weight_init_std * np.random.randn(hidden_size, output_size)
    self.params['b1'] = np.zeros(hidden_size)
    self.params['b2'] = np.zeros(output_size)

    # レイヤの生成
    self.layers = OrderedDict()
    self.layers['Affine1'] = layers.Affine(self.params['W1'], self.params['b1'])
    self.layers['Relu1'] = layers.Relu()
    self.layers['Affine2'] = layers.Affine(self.params['W2'], self.params['b2'])

    self.lastLayer = layers.SoftmaxWithLoss()

    # 順伝播
  def predict(self, x):
    for layer in self.layers.values():
      x = layer.forward(x)
      
    return x

  # 誤差
  def loss(self, x, d):
    y = self.predict(x)
    return self.lastLayer.forward(y, d)

  # 精度
  def accuracy(self, x, d):
    y = self.predict(x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)

    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

  # 勾配
  def gradient(self, x, d):
    # forward
    self.loss(x, d)

    # backward
    dout = 1
    dout = self.lastLayer.backward(dout)

    layers = list(self.layers.values())
    layers.reverse()
    for layer in layers:
      dout = layer.backward(dout)

    # 設定
    grad = {}
    grad['W1'], grad['b1'] = self.layers['Affine1'].dW, self.layers['Affine1'].db
    grad['W2'], grad['b2'] = self.layers['Affine2'].dW, self.layers['Affine2'].db

    return grad

# %% [markdown]
# 1_4_1mnist_sample 修正版

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=40, output_size=10)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval = 10

for i in range(iters_num):
  batch_mask = np.random.choice(train_size, batch_size)
  x_batch = x_train[batch_mask]
  d_batch = d_train[batch_mask]

  # 勾配
  grad = network.gradient(x_batch, d_batch)

  for key in ('W1', 'W2', 'b1', 'b2'):
    network.params[key] -= learning_rate * grad[key]

  loss = network.loss(x_batch, d_batch)
  train_loss_list.append(loss)

  if (i + 1) % plot_interval == 0:
    accr_test = network.accuracy(x_test, d_test)
    accuracies_test.append(accr_test)
    accr_train = network.accuracy(x_batch, d_batch)
    accuracies_train.append(accr_train)

    print('Generation: '+ str(i+1) + '.正答率（train) = ' + str(accr_train))
    print('             :' + str(i+1) + '.正答率(test) =' + str(accr_test))

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label='training set')
plt.plot(lists, accuracies_test, label='test set')
plt.legend(loc='lower right')
plt.title('accuracy')
plt.xlabel('count')
plt.ylabel('accuracy')
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# Generation: 10.正答率（train) = 0.09
#              :10.正答率(test) =0.1147
# Generation: 20.正答率（train) = 0.36
#              :20.正答率(test) =0.2593
# Generation: 30.正答率（train) = 0.33
#              :30.正答率(test) =0.3428
# Generation: 40.正答率（train) = 0.36
#              :40.正答率(test) =0.3518
# Generation: 50.正答率（train) = 0.41
#              :50.正答率(test) =0.3556
# Generation: 60.正答率（train) = 0.42
#              :60.正答率(test) =0.4166
# Generation: 70.正答率（train) = 0.54
#              :70.正答率(test) =0.4854
# Generation: 80.正答率（train) = 0.68
#              :80.正答率(test) =0.6394
# Generation: 90.正答率（train) = 0.67
#              :90.正答率(test) =0.65
# Generation: 100.正答率（train) = 0.81
#              :100.正答率(test) =0.6937
# Generation: 110.正答率（train) = 0.69
#              :110.正答率(test) =0.7268
# Generation: 120.正答率（train) = 0.71
#              :120.正答率(test) =0.7746
# Generation: 130.正答率（train) = 0.84
#              :130.正答率(test) =0.7684
# Generation: 140.正答率（train) = 0.79
#              :140.正答率(test) =0.7752
# Generation: 150.正答率（train) = 0.83
#              :150.正答率(test) =0.8032
# Generation: 160.正答率（train) = 0.86
#              :160.正答率(test) =0.8101
# Generation: 170.正答率（train) = 0.82
#              :170.正答率(test) =0.8223
# Generation: 180.正答率（train) = 0.83
#              :180.正答率(test) =0.8285
# Generation: 190.正答率（train) = 0.85
#              :190.正答率(test) =0.8401
# Generation: 200.正答率（train) = 0.86
#              :200.正答率(test) =0.8538
# Generation: 210.正答率（train) = 0.89
#              :210.正答率(test) =0.8359
# Generation: 220.正答率（train) = 0.85
#              :220.正答率(test) =0.8632
# Generation: 230.正答率（train) = 0.86
#              :230.正答率(test) =0.8617
# Generation: 240.正答率（train) = 0.88
#              :240.正答率(test) =0.8648
# Generation: 250.正答率（train) = 0.87
#              :250.正答率(test) =0.8667
# Generation: 260.正答率（train) = 0.89
#              :260.正答率(test) =0.8762
# Generation: 270.正答率（train) = 0.9
#              :270.正答率(test) =0.8698
# Generation: 280.正答率（train) = 0.83
#              :280.正答率(test) =0.8787
# Generation: 290.正答率（train) = 0.86
#              :290.正答率(test) =0.8816
# Generation: 300.正答率（train) = 0.89
#              :300.正答率(test) =0.8848
# Generation: 310.正答率（train) = 0.91
#              :310.正答率(test) =0.8828
# Generation: 320.正答率（train) = 0.92
#              :320.正答率(test) =0.8822
# Generation: 330.正答率（train) = 0.9
#              :330.正答率(test) =0.8795
# Generation: 340.正答率（train) = 0.86
#              :340.正答率(test) =0.8909
# Generation: 350.正答率（train) = 0.91
#              :350.正答率(test) =0.891
# Generation: 360.正答率（train) = 0.91
#              :360.正答率(test) =0.8947
# Generation: 370.正答率（train) = 0.89
#              :370.正答率(test) =0.8924
# Generation: 380.正答率（train) = 0.91
#              :380.正答率(test) =0.8928
# Generation: 390.正答率（train) = 0.85
#              :390.正答率(test) =0.8908
# Generation: 400.正答率（train) = 0.9
#              :400.正答率(test) =0.8955
# Generation: 410.正答率（train) = 0.92
#              :410.正答率(test) =0.8956
# Generation: 420.正答率（train) = 0.9
#              :420.正答率(test) =0.8975
# Generation: 430.正答率（train) = 0.83
#              :430.正答率(test) =0.8935
# Generation: 440.正答率（train) = 0.89
#              :440.正答率(test) =0.9011
# Generation: 450.正答率（train) = 0.93
#              :450.正答率(test) =0.8986
# Generation: 460.正答率（train) = 0.94
#              :460.正答率(test) =0.8997
# Generation: 470.正答率（train) = 0.92
#              :470.正答率(test) =0.9007
# Generation: 480.正答率（train) = 0.92
#              :480.正答率(test) =0.9022
# Generation: 490.正答率（train) = 0.91
#              :490.正答率(test) =0.9008
# Generation: 500.正答率（train) = 0.94
#              :500.正答率(test) =0.8986
# Generation: 510.正答率（train) = 0.91
#              :510.正答率(test) =0.9034
# Generation: 520.正答率（train) = 0.88
#              :520.正答率(test) =0.901
# Generation: 530.正答率（train) = 0.92
#              :530.正答率(test) =0.9027
# Generation: 540.正答率（train) = 0.92
#              :540.正答率(test) =0.9038
# Generation: 550.正答率（train) = 0.92
#              :550.正答率(test) =0.9045
# Generation: 560.正答率（train) = 0.91
#              :560.正答率(test) =0.9037
# Generation: 570.正答率（train) = 0.97
#              :570.正答率(test) =0.903
# Generation: 580.正答率（train) = 0.91
#              :580.正答率(test) =0.9055
# Generation: 590.正答率（train) = 0.88
#              :590.正答率(test) =0.9079
# Generation: 600.正答率（train) = 0.87
#              :600.正答率(test) =0.9055
# Generation: 610.正答率（train) = 0.92
#              :610.正答率(test) =0.9045
# Generation: 620.正答率（train) = 0.91
#              :620.正答率(test) =0.9082
# Generation: 630.正答率（train) = 0.97
#              :630.正答率(test) =0.9022
# Generation: 640.正答率（train) = 0.91
#              :640.正答率(test) =0.9114
# Generation: 650.正答率（train) = 0.95
#              :650.正答率(test) =0.9071
# Generation: 660.正答率（train) = 0.89
#              :660.正答率(test) =0.9086
# Generation: 670.正答率（train) = 0.99
#              :670.正答率(test) =0.9095
# Generation: 680.正答率（train) = 0.92
#              :680.正答率(test) =0.9068
# Generation: 690.正答率（train) = 0.94
#              :690.正答率(test) =0.9096
# Generation: 700.正答率（train) = 0.89
#              :700.正答率(test) =0.9101
# Generation: 710.正答率（train) = 0.96
#              :710.正答率(test) =0.9106
# Generation: 720.正答率（train) = 0.9
#              :720.正答率(test) =0.9114
# Generation: 730.正答率（train) = 0.94
#              :730.正答率(test) =0.9125
# Generation: 740.正答率（train) = 0.91
#              :740.正答率(test) =0.9122
# Generation: 750.正答率（train) = 0.91
#              :750.正答率(test) =0.9092
# Generation: 760.正答率（train) = 0.92
#              :760.正答率(test) =0.9155
# Generation: 770.正答率（train) = 0.98
#              :770.正答率(test) =0.9125
# Generation: 780.正答率（train) = 0.95
#              :780.正答率(test) =0.9122
# Generation: 790.正答率（train) = 0.93
#              :790.正答率(test) =0.9119
# Generation: 800.正答率（train) = 0.91
#              :800.正答率(test) =0.9129
# Generation: 810.正答率（train) = 0.91
#              :810.正答率(test) =0.912
# Generation: 820.正答率（train) = 0.94
#              :820.正答率(test) =0.9166
# Generation: 830.正答率（train) = 0.94
#              :830.正答率(test) =0.9146
# Generation: 840.正答率（train) = 0.91
#              :840.正答率(test) =0.9127
# Generation: 850.正答率（train) = 0.93
#              :850.正答率(test) =0.9138
# Generation: 860.正答率（train) = 0.86
#              :860.正答率(test) =0.9149
# Generation: 870.正答率（train) = 0.96
#              :870.正答率(test) =0.9181
# Generation: 880.正答率（train) = 0.93
#              :880.正答率(test) =0.9166
# Generation: 890.正答率（train) = 0.91
#              :890.正答率(test) =0.9127
# Generation: 900.正答率（train) = 0.92
#              :900.正答率(test) =0.9151
# Generation: 910.正答率（train) = 0.92
#              :910.正答率(test) =0.917
# Generation: 920.正答率（train) = 0.89
#              :920.正答率(test) =0.9136
# Generation: 930.正答率（train) = 0.96
#              :930.正答率(test) =0.9176
# Generation: 940.正答率（train) = 0.95
#              :940.正答率(test) =0.9151
# Generation: 950.正答率（train) = 0.95
#              :950.正答率(test) =0.9148
# Generation: 960.正答率（train) = 0.9
#              :960.正答率(test) =0.9178
# Generation: 970.正答率（train) = 0.92
#              :970.正答率(test) =0.9194
# Generation: 980.正答率（train) = 0.91
#              :980.正答率(test) =0.9176
# Generation: 990.正答率（train) = 0.92
#              :990.正答率(test) =0.9151
# Generation: 1000.正答率（train) = 0.92
#              :1000.正答率(test) =0.9205
